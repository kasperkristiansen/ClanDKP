# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
pd = pd.read_csv("daily_cwl_data.csv")

# %%
X = pd["StarsFromAttack"]
y = pd["DKP"]

plt.scatter(X, y, color="red")
plt.plot(X, y)
plt.ylabel("Stars")
plt.xlabel("DKP")
plt.grid() # Show grid
plt.show()
